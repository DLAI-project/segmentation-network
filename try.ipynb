# %% [markdown]
# <a href="https://colab.research.google.com/github/DLAI-project/project/blob/master/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive/", force_remount=True)
    google_drive_prefix = "/content/drive/My Drive"
    data_prefix = "{}/mnist/".format(google_drive_prefix)
except ModuleNotFoundError: 
    data_prefix = "data/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-61288d4af5e7> in <module>()
#       1 try:
#       2     from google.colab import drive
# ----> 3     drive.mount("/content/drive/", force_remount=True)
#       4     google_drive_prefix = "/content/drive/My Drive"
#       5     data_prefix = "{}/mnist/".format(google_drive_prefix)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     235             ': timeout during initial read of root folder; for more info: '
#     236             'https://research.google.com/colaboratory/faq.html#drive-timeout')
# --> 237       raise ValueError('mount failed' + extra_reason)
#     238     elif case == 2:
#     239       # Not already authorized, so do the authorization dance.
#
# ValueError: mount failed

# %%
abdull
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8428ad86ab36> in <module>()
#       1
# ----> 2 abdull
#
# NameError: name 'abdull' is not defined
