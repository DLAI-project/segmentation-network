# %% [markdown]
# <a href="https://colab.research.google.com/github/DLAI-project/project/blob/stefano/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c=3*2

# %%
p=12

# %%
h=58
