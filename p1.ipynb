# %% [markdown]
# <a href="https://colab.research.google.com/github/DLAI-project/project/blob/Valerio/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=11

# %%
c=1

# %%
p=12

# %%
h=58
